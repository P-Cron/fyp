# %%
from statsAnalysis.avensis08.aven08DynRespCompare import *

# %%
colsOfInterest = [
    'Device Time', '0100', '011c obd standards vehicle conforms to', '0120', '0140', '0901 vin message count', '0903', '0905', '0906', 'Barometric pressure (from vehicle)(psi)', 'Distance travelled with MIL/CEL lit(miles)', 'EGR Commanded(%)', 'EGR Error(%)', 'Engine Coolant Temperature(°C)', 'Engine Load(%)', 'Engine RPM(rpm)', 
    'Fuel Rail Pressure(psi)', 'Intake Air Temperature(°C)', 
    'Intake Manifold Pressure(psi)', 'Kilometers Per Litre(Instant)(kpl)', 
    'Kilometers Per Litre(Long Term Average)(kpl)', 'Litres Per 100 Kilometer(Long Term Average)(l/100km)', 
    'Mass Air Flow Rate(g/s)', 'Miles Per Gallon(Instant)(mpg)', 'Miles Per Gallon(Long Term Average)(mpg)',
     'Throttle Position(Manifold)(%)', 'Trip average KPL(kpl)', 'Trip average MPG(mpg)', 
    'Turbo Boost & Vacuum Gauge(psi)', 'Voltage (Control Module)(V)', 'Voltage (OBD Adapter)(V)', 'Volumetric Efficiency (Calculated)(%)']

for col in colsOfInterest:
    printDescribes(col, avenDfList)
# Out:
# 1
# count                          420
# unique                         420
# top       12-Feb-2022 12:21:44.624
# freq                             1
# Name: Device Time, dtype: object
# 2
# count                          533
# unique                         533
# top       09-Apr-2022 12:04:50.021
# freq                             1
# Name: Device Time, dtype: object
# 1
# count    420.0
# mean     152.0
# std        0.0
# min      152.0
# 25%      152.0
# 50%      152.0
# 75%      152.0
# max      152.0
# Name: 0100, dtype: float64
# 2
# count    5.330000e+02
# mean     2.554036e+09
# std      0.000000e+00
# min      2.554036e+09
# 25%      2.554036e+09
# 50%      2.554036e+09
# 75%      2.554036e+09
# max      2.554036e+09
# Name: 0100, dtype: float64
# 1
# count    420.0
# mean       6.0
# std        0.0
# min        6.0
# 25%        6.0
# 50%        6.0
# 75%        6.0
# max        6.0
# Name: 011c obd standards vehicle conforms to, dtype: float64
# 2
# count    533.0
# ...

# %%
colsOfInterest = [
    'Device Time', '0100', '011c obd standards vehicle conforms to', '0120', '0140', '0901 vin message count', '0903', '0905', '0906', 
    'Barometric pressure (from vehicle)(psi)', # seems to be at a constant all the time, 
    # but is purely dependant on the external environment so do not use
     'Distance travelled with MIL/CEL lit(miles)', 
     'EGR Commanded(%)', # not sure, check when not running
      'EGR Error(%)', # same as EGR commanded, check when not running
      # neither of them are any use as was found out
       'Engine Coolant Temperature(°C)',
       'Engine Load(%)',
        'Engine RPM(rpm)', 
    'Fuel Rail Pressure(psi)', 'Intake Air Temperature(°C)', 
    'Intake Manifold Pressure(psi)', # seems surprisingly constant but will not take, as often dependant on temperature as saw before
     'Kilometers Per Litre(Instant)(kpl)', 
    'Kilometers Per Litre(Long Term Average)(kpl)', 'Litres Per 100 Kilometer(Long Term Average)(l/100km)', 
    'Mass Air Flow Rate(g/s)', 'Miles Per Gallon(Instant)(mpg)', 
    'Miles Per Gallon(Long Term Average)(mpg)', # does not give a value for some time, though it is then stable, maybe best not to use because it is missing a value for some time 
    'Speed (OBD)(mph)', 
    'Throttle Position(Manifold)(%)', # seems good, check again when vehicle not yet started
     'Trip average KPL(kpl)', 'Trip average Litres/100 KM(l/100km)', 'Trip average MPG(mpg)', 
    'Turbo Boost & Vacuum Gauge(psi)',  # looks useful here but have also seen can be very dependant on temperature 
     'Voltage (Control Module)(V)', 'Voltage (OBD Adapter)(V)', # neither are useful 
     'Volumetric Efficiency (Calculated)(%)' # have seen before can be useful, but cannot use because did not collect speed when took first reading
     ]

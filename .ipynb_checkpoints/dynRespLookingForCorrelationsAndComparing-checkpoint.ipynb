# %%
import pandas as pd
from pandas.plotting import scatter_matrix


df = pd.read_csv("torqueLogs\\trackLog-2022-Jan-16_17-42-53.csv")
df1 = df[['Device Time', '0903', 'Engine Coolant Temperature(°C)']].copy()
jan16LogsPath = 'torqueLogs\\trackLog-2022-Jan-16_17-42-53.csv'
jan23LogsPath = 'torqueLogs\\trackLog-2022-Jan-23_19-26-14.csv'
jan27LogsPath = 'torqueLogs\\trackLog-2022-Jan-27_12-40-54.csv'
jan29LogsPath = 'torqueLogs\\trackLog-2022-Jan-29_00-56-43_FIXED.csv'
mar12LogsPath = 'torqueLogs\\trackLog-2022-Mar-12_17-27-39_Accord08.csv'

df1 = pd.read_csv(jan16LogsPath)
df2 = pd.read_csv(jan23LogsPath)
df3 = pd.read_csv(jan27LogsPath)
df4 = pd.read_csv(jan29LogsPath, on_bad_lines='skip') # this csv seems to be corrupted
df5 = pd.read_csv(mar12LogsPath, on_bad_lines='skip')

for df in [df1, df2, df3]:
    print("-----Next log-----")
    # print(df.columns)
    # for thing in df.tail(1):
    #     print(thing)

    #print(df.tail(1))
    # remove blanks
    # df = df.loc[df['Engine RPM(rpm)']!='0']
    print("--- RPM Stats ---")
    df = df[(df["Engine RPM(rpm)"] > 100)].copy() # how to get stuff over 100
    print(df.head(1)[['Engine RPM(rpm)']])

    # some other stat should check out now
    print(df['Engine RPM(rpm)'].describe())

for df in [df1, df2, df3]:
    print("-----Next log-----")
    print("--- Fuel Rail Pressure(psi) Stats ---")
    print(df.head(1)[['Fuel Rail Pressure(psi)']])

    # some other stat should check out now
    print(df['Fuel Rail Pressure(psi)'].describe())

# fuel rail pressure isn't any use really it seems
# Out:
# -----Next log-----
# --- RPM Stats ---
#    Engine RPM(rpm)
# 0              819
# count     36.000000
# mean     835.583333
# std       30.848362
# min      819.000000
# 25%      819.000000
# 50%      821.000000
# 75%      830.500000
# max      935.000000
# Name: Engine RPM(rpm), dtype: float64
# -----Next log-----
# --- RPM Stats ---
#    Engine RPM(rpm)
# 0              862
# count     764.000000
# mean     1513.756545
# std       407.518647
# min       771.000000
# 25%      1281.000000
# 50%      1555.000000
# 75%      1841.500000
# max      2403.000000
# Name: Engine RPM(rpm), dtype: float64
# -----Next log-----
# --- RPM Stats ---
#     Engine RPM(rpm)
# 13              890
# count     292.000000
# mean      872.845890
# std       145.237808
# min       760.000000
# 25%       818.000000
# 50%       822.500000
# 75%       847.000000
# max      1504.000000
# Name: Engine RPM(rpm), dtype: float64
# -----Next log-----
# --- Fuel Rail Pressure(psi) Stats ---
#    Fuel Rail Pressure(psi)
# 0              4429.452637
# count      42.000000
# mean     3946.097023
# std      1310.729755
# min       285.724335
# 25%      4341.704590
# 50%      4429.452637
# 75%      4485.291992
# max      4876.168945
# Name: Fuel Rail Pressure(psi), dtype: float64
# -----Next log-----
# --- Fuel Rail Pressure(psi) Stats ---
#    Fuel Rail Pressure(psi)
# 0              4844.260254
# count      764.000000
# mean     10829.601520
# std       4645.224041
# min       4111.819824
# 25%       6725.399902
# 50%      10581.953125
# 75%      15459.572266
# max      19411.851562
# Name: Fuel Rail Pressure(psi), dtype: float64
# -----Next log-----
# --- Fuel Rail Pressure(psi) Stats ---
#    Fuel Rail Pressure(psi)
# 0                94.274529
# count      318.000000
# mean      4740.517425
# std       2228.814177
# min         94.274529
# 25%       4429.452637
# 50%       4620.902344
# 75%       4780.443848
# max      13642.250000
# Name: Fuel Rail Pressure(psi), dtype: float64

# %%
validColumns = ['Device Time', '0100', '011c obd standards vehicle conforms to', '0120', '0903', 'CO₂ in g/km (Average)(g/km)', 'Distance travelled with MIL/CEL lit(miles)', 'EGR Commanded(%)', 'Engine Coolant Temperature(°C)', 'Engine Load(%)', 'Engine RPM(rpm)', 'Fuel Rail Pressure(psi)', 'Intake Air Temperature(°C)', 'Intake Manifold Pressure(psi)', 'Mass Air Flow Rate(g/s)', 'pids supported 01-20', 'service 09 pids supported', 'Turbo Boost & Vacuum Gauge(psi)', 'Voltage (OBD Adapter)(V)', 'Volumetric Efficiency (Calculated)(%)']
dynamicColumns = ['CO₂ in g/km (Average)(g/km)', 'Distance travelled with MIL/CEL lit(miles)', 'EGR Commanded(%)', 'Engine Coolant Temperature(°C)', 'Engine Load(%)', 'Engine RPM(rpm)', 'Fuel Rail Pressure(psi)', 'Intake Air Temperature(°C)', 'Intake Manifold Pressure(psi)', 'Mass Air Flow Rate(g/s)', 'Turbo Boost & Vacuum Gauge(psi)', 'Voltage (OBD Adapter)(V)', 'Volumetric Efficiency (Calculated)(%)']

df3 = df3[dynamicColumns].copy()
df3.corr()
# Out:
#                                             Distance travelled with MIL/CEL lit(miles)  \
# Distance travelled with MIL/CEL lit(miles)                                         NaN
# EGR Commanded(%)                                                                   NaN
# Engine Coolant Temperature(°C)                                                     NaN
# Engine Load(%)                                                                     NaN
# Engine RPM(rpm)                                                                    NaN
# Fuel Rail Pressure(psi)                                                            NaN
# Intake Air Temperature(°C)                                                         NaN
# Intake Manifold Pressure(psi)                                                      NaN
# Mass Air Flow Rate(g/s)                                                            NaN
# Turbo Boost & Vacuum Gauge(psi)                                                    NaN
# Voltage (OBD Adapter)(V)                                                           NaN
#
#                                             EGR Commanded(%)  \
# Distance travelled with MIL/CEL lit(miles)               NaN
# EGR Commanded(%)                                    1.000000
# Engine Coolant Temperature(°C)                      0.200131
# Engine Load(%)                                      0.782579
# Engine RPM(rpm)                                     0.388379
# Fuel Rail Pressure(psi)                             0.402768
# Intake Air Temperature(°C)                         -0.123889
# Intake Manifold Pressure(psi)                       0.067417
# Mass Air Flow Rate(g/s)                            -0.284541
# Turbo Boost & Vacuum Gauge(psi)                     0.067417
# Voltage (OBD Adapter)(V)                            0.116971
#
#                                             Engine Coolant Temperature(°C)  \
# Distance travelled with MIL/CEL lit(miles)                             NaN
# EGR Commanded(%)                                                  0.200131
# Engine Coolant Temperature(°C)                                    1.000000
# Engine Load(%)                                                    0.141103
# Engine RPM(rpm)                                                  -0.007761
# Fuel Rail Pressure(psi)                                          -0.048101
# Intake Air Temperature(°C)                                        0.806215
# Intake Manifold Pressure(psi)                                     0.101176
# Mass Air Flow Rate(g/s)                                          -0.201313
# Turbo Boost & Vacuum Gauge(psi)                                   0.101176
# Voltage (OBD Adapter)(V)                                          0.282095
#
#                                             Engine Load(%)  Engine RPM(rpm)  \
# Distance travelled with MIL/CEL lit(miles)             NaN              NaN
# EGR Commanded(%)                                  0.782579         0.388379
# Engine Coolant Temperature(°C)                    0.141103        -0.007761
# Engine Load(%)                                    1.000000         0.563433
# Engine RPM(rpm)                                   0.563433         1.000000
# Fuel Rail Pressure(psi)                           0.509740         0.786129
# Intake Air Temperature(°C)                       -0.259549        -0.346609
# Intake Manifold Pressure(psi)                    -0.141146        -0.432398
# Mass Air Flow Rate(g/s)                           0.056303         0.712545
# Turbo Boost & Vacuum Gauge(psi)                  -0.141146        -0.432398
# Voltage (OBD Adapter)(V)                          0.384004         0.707460
#
#                                             Fuel Rail Pressure(psi)  \
# Distance travelled with MIL/CEL lit(miles)                      NaN
# EGR Commanded(%)                                           0.402768
# Engine Coolant Temperature(°C)                            -0.048101
# Engine Load(%)                                             0.509740
# Engine RPM(rpm)                                            0.786129
# Fuel Rail Pressure(psi)                                    1.000000
# Intake Air Temperature(°C)                                -0.252653
# Intake Manifold Pressure(psi)                             -0.174470
# Mass Air Flow Rate(g/s)                                    0.591796
# Turbo Boost & Vacuum Gauge(psi)                           -0.174470
# Voltage (OBD Adapter)(V)                                   0.550216
#
#                                             Intake Air Temperature(°C)  \
# Distance travelled with MIL/CEL lit(miles)                         NaN
# EGR Commanded(%)                                             -0.123889
# Engine Coolant Temperature(°C)                                0.806215
# Engine Load(%)                                               -0.259549
# Engine RPM(rpm)                                              -0.346609
# Fuel Rail Pressure(psi)                                      -0.252653
# Intake Air Temperature(°C)                                    1.000000
# Intake Manifold Pressure(psi)                                 0.388915
# Mass Air Flow Rate(g/s)                                      -0.339334
# Turbo Boost & Vacuum Gauge(psi)                               0.388915
# Voltage (OBD Adapter)(V)                                     -0.083075
#
#                                             Intake Manifold Pressure(psi)  \
# Distance travelled with MIL/CEL lit(miles)                            NaN
# EGR Commanded(%)                                                 0.067417
# Engine Coolant Temperature(°C)                                   0.101176
# Engine Load(%)                                                  -0.141146
# Engine RPM(rpm)                                                 -0.432398
# Fuel Rail Pressure(psi)                                         -0.174470
# Intake Air Temperature(°C)                                       0.388915
# Intake Manifold Pressure(psi)                                    1.000000
# Mass Air Flow Rate(g/s)                                         -0.512344
# Turbo Boost & Vacuum Gauge(psi)                                  1.000000
# Voltage (OBD Adapter)(V)                                        -0.553782
#
#                                             Mass Air Flow Rate(g/s)  \
# Distance travelled with MIL/CEL lit(miles)                      NaN
# EGR Commanded(%)                                          -0.284541
# Engine Coolant Temperature(°C)                            -0.201313
# Engine Load(%)                                             0.056303
# Engine RPM(rpm)                                            0.712545
# Fuel Rail Pressure(psi)                                    0.591796
# Intake Air Temperature(°C)                                -0.339334
# Intake Manifold Pressure(psi)                             -0.512344
# Mass Air Flow Rate(g/s)                                    1.000000
# Turbo Boost & Vacuum Gauge(psi)                           -0.512344
# Voltage (OBD Adapter)(V)                                   0.644199
#
#                                             Turbo Boost & Vacuum Gauge(psi)  \
# Distance travelled with MIL/CEL lit(miles)                              NaN
# EGR Commanded(%)                                                   0.067417
# Engine Coolant Temperature(°C)                                     0.101176
# Engine Load(%)                                                    -0.141146
# Engine RPM(rpm)                                                   -0.432398
# Fuel Rail Pressure(psi)                                           -0.174470
# Intake Air Temperature(°C)                                         0.388915
# Intake Manifold Pressure(psi)                                      1.000000
# Mass Air Flow Rate(g/s)                                           -0.512344
# Turbo Boost & Vacuum Gauge(psi)                                    1.000000
# Voltage (OBD Adapter)(V)                                          -0.553782
#
#                                             Voltage (OBD Adapter)(V)
# Distance travelled with MIL/CEL lit(miles)                       NaN
# EGR Commanded(%)                                            0.116971
# Engine Coolant Temperature(°C)                              0.282095
# Engine Load(%)                                              0.384004
# Engine RPM(rpm)                                             0.707460
# Fuel Rail Pressure(psi)                                     0.550216
# Intake Air Temperature(°C)                                 -0.083075
# Intake Manifold Pressure(psi)                              -0.553782
# Mass Air Flow Rate(g/s)                                     0.644199
# Turbo Boost & Vacuum Gauge(psi)                            -0.553782
# Voltage (OBD Adapter)(V)                                    1.000000

# %%
m = scatter_matrix(df3, figsize=(30, 30))
# Out:
# C:\Users\Pádraig\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\plotting\_matplotlib\misc.py:91: UserWarning: Attempting to set identical left == right == 37.28227234 results in singular transformations; automatically expanding.
#   ax.set_xlim(boundaries_list[i])
# C:\Users\Pádraig\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\plotting\_matplotlib\misc.py:101: UserWarning: Attempting to set identical bottom == top == 37.28227234 results in singular transformations; automatically expanding.
#   ax.set_ylim(boundaries_list[i])
# C:\Users\Pádraig\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\plotting\_matplotlib\misc.py:100: UserWarning: Attempting to set identical left == right == 37.28227234 results in singular transformations; automatically expanding.
#   ax.set_xlim(boundaries_list[j])

# %%
validColumns = ['Device Time', '0100', '011c obd standards vehicle conforms to', '0120', '0903', 'CO₂ in g/km (Average)(g/km)', 'Distance travelled with MIL/CEL lit(miles)', 'EGR Commanded(%)', 'Engine Coolant Temperature(°C)', 'Engine Load(%)', 'Engine RPM(rpm)', 'Fuel Rail Pressure(psi)', 'Intake Air Temperature(°C)', 'Intake Manifold Pressure(psi)', 'Mass Air Flow Rate(g/s)', 'pids supported 01-20', 'service 09 pids supported', 'Turbo Boost & Vacuum Gauge(psi)', 'Voltage (OBD Adapter)(V)', 'Volumetric Efficiency (Calculated)(%)']
dynamicColumns = ['CO₂ in g/km (Average)(g/km)', 'Distance travelled with MIL/CEL lit(miles)', 'EGR Commanded(%)', 'Engine Coolant Temperature(°C)', 'Engine Load(%)', 'Engine RPM(rpm)', 'Fuel Rail Pressure(psi)', 'Intake Air Temperature(°C)', 'Intake Manifold Pressure(psi)', 'Mass Air Flow Rate(g/s)', 'Turbo Boost & Vacuum Gauge(psi)', 'Voltage (OBD Adapter)(V)', 'Volumetric Efficiency (Calculated)(%)']

df5 = df5[dynamicColumns].copy()
df5.corr()
# Out:
#                                             Distance travelled with MIL/CEL lit(miles)  \
# Distance travelled with MIL/CEL lit(miles)                                         NaN
# EGR Commanded(%)                                                                   NaN
# Engine Coolant Temperature(°C)                                                     NaN
# Engine RPM(rpm)                                                                    NaN
# Fuel Rail Pressure(psi)                                                            NaN
# Intake Air Temperature(°C)                                                         NaN
# Intake Manifold Pressure(psi)                                                      NaN
# Mass Air Flow Rate(g/s)                                                            NaN
# Turbo Boost & Vacuum Gauge(psi)                                                    NaN
# Voltage (OBD Adapter)(V)                                                           NaN
#
#                                             EGR Commanded(%)  \
# Distance travelled with MIL/CEL lit(miles)               NaN
# EGR Commanded(%)                                         NaN
# Engine Coolant Temperature(°C)                           NaN
# Engine RPM(rpm)                                          NaN
# Fuel Rail Pressure(psi)                                  NaN
# Intake Air Temperature(°C)                               NaN
# Intake Manifold Pressure(psi)                            NaN
# Mass Air Flow Rate(g/s)                                  NaN
# Turbo Boost & Vacuum Gauge(psi)                          NaN
# Voltage (OBD Adapter)(V)                                 NaN
#
#                                             Engine Coolant Temperature(°C)  \
# Distance travelled with MIL/CEL lit(miles)                             NaN
# EGR Commanded(%)                                                       NaN
# Engine Coolant Temperature(°C)                                    1.000000
# Engine RPM(rpm)                                                  -0.206455
# Fuel Rail Pressure(psi)                                           0.240774
# Intake Air Temperature(°C)                                        0.428206
# Intake Manifold Pressure(psi)                                          NaN
# Mass Air Flow Rate(g/s)                                          -0.115684
# Turbo Boost & Vacuum Gauge(psi)                                        NaN
# Voltage (OBD Adapter)(V)                                          0.163578
#
#                                             Engine RPM(rpm)  \
# Distance travelled with MIL/CEL lit(miles)              NaN
# EGR Commanded(%)                                        NaN
# Engine Coolant Temperature(°C)                    -0.206455
# Engine RPM(rpm)                                    1.000000
# Fuel Rail Pressure(psi)                            0.404255
# Intake Air Temperature(°C)                        -0.124134
# Intake Manifold Pressure(psi)                           NaN
# Mass Air Flow Rate(g/s)                            0.211879
# Turbo Boost & Vacuum Gauge(psi)                         NaN
# Voltage (OBD Adapter)(V)                           0.352325
#
#                                             Fuel Rail Pressure(psi)  \
# Distance travelled with MIL/CEL lit(miles)                      NaN
# EGR Commanded(%)                                                NaN
# Engine Coolant Temperature(°C)                             0.240774
# Engine RPM(rpm)                                            0.404255
# Fuel Rail Pressure(psi)                                    1.000000
# Intake Air Temperature(°C)                                -0.153190
# Intake Manifold Pressure(psi)                                   NaN
# Mass Air Flow Rate(g/s)                                   -0.324103
# Turbo Boost & Vacuum Gauge(psi)                                 NaN
# Voltage (OBD Adapter)(V)                                   0.185149
#
#                                             Intake Air Temperature(°C)  \
# Distance travelled with MIL/CEL lit(miles)                         NaN
# EGR Commanded(%)                                                   NaN
# Engine Coolant Temperature(°C)                                0.428206
# Engine RPM(rpm)                                              -0.124134
# Fuel Rail Pressure(psi)                                      -0.153190
# Intake Air Temperature(°C)                                    1.000000
# Intake Manifold Pressure(psi)                                      NaN
# Mass Air Flow Rate(g/s)                                      -0.075458
# Turbo Boost & Vacuum Gauge(psi)                                    NaN
# Voltage (OBD Adapter)(V)                                     -0.125223
#
#                                             Intake Manifold Pressure(psi)  \
# Distance travelled with MIL/CEL lit(miles)                            NaN
# EGR Commanded(%)                                                      NaN
# Engine Coolant Temperature(°C)                                        NaN
# Engine RPM(rpm)                                                       NaN
# Fuel Rail Pressure(psi)                                               NaN
# Intake Air Temperature(°C)                                            NaN
# Intake Manifold Pressure(psi)                                         NaN
# Mass Air Flow Rate(g/s)                                               NaN
# Turbo Boost & Vacuum Gauge(psi)                                       NaN
# Voltage (OBD Adapter)(V)                                              NaN
#
#                                             Mass Air Flow Rate(g/s)  \
# Distance travelled with MIL/CEL lit(miles)                      NaN
# EGR Commanded(%)                                                NaN
# Engine Coolant Temperature(°C)                            -0.115684
# Engine RPM(rpm)                                            0.211879
# Fuel Rail Pressure(psi)                                   -0.324103
# Intake Air Temperature(°C)                                -0.075458
# Intake Manifold Pressure(psi)                                   NaN
# Mass Air Flow Rate(g/s)                                    1.000000
# Turbo Boost & Vacuum Gauge(psi)                                 NaN
# Voltage (OBD Adapter)(V)                                   0.130170
#
#                                             Turbo Boost & Vacuum Gauge(psi)  \
# Distance travelled with MIL/CEL lit(miles)                              NaN
# EGR Commanded(%)                                                        NaN
# Engine Coolant Temperature(°C)                                          NaN
# Engine RPM(rpm)                                                         NaN
# Fuel Rail Pressure(psi)                                                 NaN
# Intake Air Temperature(°C)                                              NaN
# Intake Manifold Pressure(psi)                                           NaN
# Mass Air Flow Rate(g/s)                                                 NaN
# Turbo Boost & Vacuum Gauge(psi)                                         NaN
# Voltage (OBD Adapter)(V)                                                NaN
#
#                                             Voltage (OBD Adapter)(V)
# Distance travelled with MIL/CEL lit(miles)                       NaN
# EGR Commanded(%)                                                 NaN
# Engine Coolant Temperature(°C)                              0.163578
# Engine RPM(rpm)                                             0.352325
# Fuel Rail Pressure(psi)                                     0.185149
# Intake Air Temperature(°C)                                 -0.125223
# Intake Manifold Pressure(psi)                                    NaN
# Mass Air Flow Rate(g/s)                                     0.130170
# Turbo Boost & Vacuum Gauge(psi)                                  NaN
# Voltage (OBD Adapter)(V)                                    1.000000

# %%
df4.describe()
# Out:
#                      Device Time  0-100kph Time(s) 0100  \
# count                        150               150  150
# unique                       150                 1    2
# top     29-Jan-2022 00:56:52.202                 -  152
# freq                           1               150   97
#
#        011c obd standards vehicle conforms to 0120 0140 0160  \
# count                                     150  150  150  150
# unique                                      2    2    1    1
# top                                         6  160    -    -
# freq                                       97   97  150  150
#
#        0901 vin message count 0902 0903  ... Intake Manifold Pressure(psi)  \
# count                     150  150  150  ...                           150
# unique                      1    1    2  ...                             2
# top                         -    -    3  ...                   14.93888664
# freq                      150  150   96  ...                           102
#
#        Mass Air Flow Rate(g/s) O2 Sensor4 Voltage(V)  \
# count                      150                   150
# unique                      17                     1
# top                          -                     -
# freq                        48                   150
#
#        Odometer(from ECU)(miles) pids supported 01-20  \
# count                        150                  150
# unique                         1                    2
# top                            -                  152
# freq                         150                   94
#
#        service 09 pids supported Torque(Nm) Turbo Boost & Vacuum Gauge(psi)  \
# count                        150        150                             150
# unique                         2          1                               2
# top                           48          -                      0.23888683
# freq                          94        150                             102
#
#        Voltage (OBD Adapter)(V) Volumetric Efficiency (Calculated)(%)
# count                       150                                   150
# unique                        3                                     4
# top                 12.69999981                                     -
# freq                         84                                    57
#
# [4 rows x 61 columns]
